# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
from skimage.exposure import histogram
img = mpimg.imread('bogel.jfif')
plt.imshow(img)

# %%
ret, img_binary = cv2.threshold(img, 50, 320, cv2.THRESH_BINARY)
plt.imshow(img_binary)
plt.show()

# %%
freq, bins = histogram(img)
plt.step(bins, freq*1.0/freq.sum())
plt.xlabel('Intensity value')
plt.ylabel('Fraction of pixels');

# %% [markdown]
# Agil Nanda Irmawan

# %% [markdown]
# NIM = 23421032 | yang dipakai 032 tetapi disuruh mengubah ke 320

# %% [markdown]
# Nilai Maksimum = 320
